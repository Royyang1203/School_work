# %%
import numpy as np
num_list = []
num2_list = []

while True:
    num = int(input())
    if num == -1:
        break
    num_list.append(num)

while True:
    num2 = int(input())
    if num2 == -1:
        break
    num2_list.append(num2)
    
num1_matrix = np.array(num_list).reshape(-1,3)
num2_matrix = np.array(num2_list).reshape(-1,3)

num3_matrix = (num1_matrix + num2_matrix)/2
num3_matrix[:,0] += 10
num3_matrix[num3_matrix < 60] = -1
num3_matrix[num3_matrix >= 100] = 100


print(num1_matrix,num2_matrix,num3_matrix, sep=" \n\n")

# %%
from bs4 import BeautifulSoup



import requests



res = requests.get("https://www.taiwanlottery.com.tw/lotto/lotto649/history.aspx")



soup = BeautifulSoup(res.text, 'html.parser')



date = str(input())



num = str(input())



da = ['112000037', '112000036', '112000035', '112000034', '112000033', '112000032', '112000031', '112000030', '112000029', '112000028']



number = []



for i in range(len(da)):



    if date == da[i]:



        index = i



        



for i in range(1,7):



    number.append(soup.find("span", {"id":f"Lotto649Control_history_dlQuery_SNo{i}_{index}"}).text)



number.append(soup.find("span", {"id":f"Lotto649Control_history_dlQuery_No7_{index}"}).text)



num = num.split(", ")



for i in range(len(num)):



    if len(num[i]) < 2:



        num[i] = "0" + num[i]



count = 0



for i in range(6):



    for j in range(6):



        if num[i] == number[j]:



            count += 1



flag = 0



for i in range(len(num)):



    if num[i] == number[6]:



        flag = 1



if count == 6:



    print("Jackpot")



elif count == 5:



    if flag == 1:



        print("Second prize")



    else:



        print("Third prize")



elif count == 4:



    if flag == 1:



        print("Fourth prize")



    else:



        print("Fifth prize")



elif count == 3:



    if flag == 1:



        print("Sixth prize")



    else:



        print("Eighth prize")



elif count == 2 and flag == 1:



    print("Seventh prize")



else:



    print("NO")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 71
#      67     print("投注號碼格式不正確！")
#      69 else:
# ---> 71     result = check_lottery_numbers(date, numbers)
#      73     print("中獎方式：", result)
#
# Cell In[3], line 21, in check_lottery_numbers(date, numbers)
#      19 def check_lottery_numbers(date, numbers):
# ---> 21     winning_numbers, special_number = get_winning_numbers(date)
#      23     num_matching = len(set(numbers) & set(winning_numbers))
#      25     if num_matching == 6:
#
# Cell In[3], line 13, in get_winning_numbers(date)
#       9 response = requests.get(url, params={"Lotto649Control_history$DropDownList1": date})
#      11 soup = BeautifulSoup(response.text, "html.parser")
# ---> 13 numbers = soup.find("div", class_="ball_tx").text.strip().split()
#      15 special_number = soup.find("div", class_="ball_red").text.strip()
#      17 return numbers, special_number
#
# AttributeError: 'NoneType' object has no attribute 'text'
