# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

plt.rcParams['font.sans-serif']=['Microsoft JhengHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

df = pd.read_csv("data.csv", encoding= 'ANSI')
df

print(df.columns[1:])
a = df.columns[1:]
print(df.iloc[0, 1:])

fig = plt.figure(figsize = (16, 16), facecolor = "lightblue")  
ax1 = fig.add_subplot(221)
ax1.plot(a, df.iloc[0, 1:], "b-")
plt.xticks(rotation = 90)

ax2 =fig.add_subplot(224)
ax2.plot([1, 2, 3], [2, 5, 8], "r--")
plt.show()
# Out:
# Index(['基隆市', '台北市', '新北市', '桃園市', '新竹縣市', '苗栗縣', '台中市', '南投市', '彰化縣', '雲林縣',
#        '嘉義縣市', '台南市', '高雄市', '屏東縣', '台東縣', '花蓮縣', '宜蘭縣'],
#       dtype='object')
# 基隆市      1003
# 台北市      5538
# 新北市     10151
# 桃園市      4814
# 新竹縣市      724
# 苗栗縣       194
# 台中市      1680
# 南投市       138
# 彰化縣       313
# 雲林縣       257
# 嘉義縣市      212
# 台南市       795
# 高雄市      1021
# 屏東縣       428
# 台東縣       117
# 花蓮縣       450
# 宜蘭縣       525
# Name: 0, dtype: object
